# %% [markdown]
# # SQL Queries
# ## Workbook contains class that contcts to Postgre and performs simple actions involving inputation of data from retreived by etl.py

# %% [markdown]
# ## The task is to create the following tables and then input provided data:
#
# ### Fact Table
#
# 1) songplays - records in log data associated with song plays i.e. records with page NextSong
# - columns: songplay_id, start_time, user_id, level, song_id, artist_id, session_id, location, user_agent
#
# ### Dimension Tables
#
# 1) users - users in the app
# - columns: user_id, first_name, last_name, gender, level
#
# 2) songs - songs in music database
# - columns: song_id, title, artist_id, year, duration
#
# 3) artists - artists in music database
# - columns: artist_id, name, location, latitude, longitude
#
# 4) time - timestamps of records in songplays broken down into specific units
# - columns: start_time, hour, day, week, month, year, weekday

# %%
import psycopg2
import re
from etl import *
# Out:
# Folder data is in your CWD!

# %%
class Postgres:
    '''Connects to Postres and performs simple actions'''
    
    _tables = {}
    
    def __init__(self, host = 'localhost', port='5432', user='postgres', password='student'):
        '''Creates attributes for connecting to database and performin queries'''
        
        self.host = host
        self.port = port
        self.user = user
        self.password = password
        self.con = None
        self.cur = None
        
    def __enter__(self):
        '''Connects to Postgre upon using contex manager'''
        
        self.con = psycopg2.connect(host=self.host, port=self.port, user=self.user, password=self.password)
        self.cur = self.con.cursor()
        self.con.set_session(autocommit=True)
        return self

    def create_database(self, db='sparkifydb'):
        '''Drops database if exists and creates new one'''
        
        self.cur.execute("DROP DATABASE IF EXISTS " + db + ';')
        self.cur.execute('CREATE DATABASE ' + db + ';')
    
    def connect_to_db(self, db='sparkifydb'):
        '''Connects to database'''
        
        self.con = psycopg2.connect(host=self.host, port=self.port, user=self.user, password=self.password, dbname=db)
        self.cur = self.con.cursor()
        self.con.set_session(autocommit=True)
        print('You have been conected to database: '+ db)
        
    def list_tables(self):
        '''Lists tables in database'''
        
        self.cur.execute("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public' ORDER BY table_name;")
        row = self.cur.fetchone()
        tables = ''
        while row:
            tables = tables + str(row)
            row = self.cur.fetchone()
        tables = re.sub(r"[\(\)]",'',tables)[:-1]
        print('At your current DB you have the following tables: '+tables)
        
    def create_table(self, queries):
        '''Creates table'''
        
        assert type(queries)==list, 'List of queries should be provided; The queries should start with CREATE TABLE'
        for query in queries:
            
            assert 'CREATE TABLE' in query, 'The query should start with CREATE TABLE'
            
            name = query.split('CREATE TABLE ')[1].split(' ')[0]
            self.cur.execute('DROP TABLE IF EXISTS '+name+';')
            self.cur.execute(query)
            
            columns = query.split('(')[1].split(')')[0].split(',')
            columns = [col.split( )[0].strip() for col in columns]
            Postgres._tables[name] = columns
            
            print('Table '+name+' created successfully!')
    
    
    def insert_data(self, table_name, data):
        '''Inserts data to table'''
        
        assert table_name in Postgres._tables, 'Create a table beforehand!'
        assert type(data)== list, 'This should be a list of tuples!'
        
        for d in data:

            insert_query = 'INSERT INTO '+ table_name + ' (' + ', '.join(Postgres._tables[table_name])+') VALUES '+ \
                        '(' + '%s, ' * (len(Postgres._tables[table_name])-1)+'%s) ON CONFLICT \
                        ('+Postgres._tables[table_name][0]+') DO NOTHING;'
            
            self.cur.execute(insert_query, d)
            
    def print_columns(self, table_name):
        '''Prints column names of a table'''
        
        assert table_name in Postgres._tables, 'Create a table beforehand!'
        self.cur.execute('Select * FROM '+table_name+' LIMIT 0')
        colnames = [desc[0] for desc in self.cur.description]
        print(colnames)
    
            
    def print_data(self, table_name):
        '''Prints all data of a table'''
        
        self.cur.execute('SELECT * FROM '+table_name+';')
        row = self.cur.fetchone()
        
        print(table_name)
        print(', '.join(Postgres._tables[table_name]))
        while row:
            print(row)
            row = self.cur.fetchone()
        
    def execute_query(self, query):
        '''Executes a custom query'''
        
        self.cur.execute(query)
        
    def __exit__(self, exc_type, exc_val, exc_tb):
        '''Closes the cursor and conection via contex manager'''
        
        self.cur.close()
        self.con.close()
        print('Conection closed!')

# %%
songplays = '''CREATE TABLE songplays 
                (songplay_id INT PRIMARY KEY, start_time TIMESTAMP NOT NULL, user_id INT NOT NULL, level VARCHAR NOT NULL,
                song_id VARCHAR NOT NULL, artist_id VARCHAR NOT NULL, session_id INT NOT NULL, 
                location VARCHAR NOT NULL, user_agent VARCHAR NOT NULL);'''
users = '''CREATE TABLE users 
                (user_id INT PRIMARY KEY, first_name VARCHAR, last_name VARCHAR, gender VARCHAR, level VARCHAR);'''
songs = '''CREATE TABLE songs (song_id VARCHAR PRIMARY KEY, title VARCHAR NOT NULL, artist_id VARCHAR NOT NULL, 
year INT NOT NULL, duration INT NOT NULL)'''
artists = '''CREATE TABLE artists (artist_id VARCHAR PRIMARY KEY, name VARCHAR NOT NULL, location VARCHAR NOT NULL,
latitude FLOAT NOT NULL, longitude FLOAT NOT NULL)'''
time = '''CREATE TABLE time (start_time TIMESTAMP PRIMARY KEY, hour INT, day INT, week INT, month INT,
                year INT, weekday INT)'''

queries = [songplays, users, songs, artists, time]

# %%
# created for the sake of testing
songplay_table_create = songplays
user_table_create = users
song_table_create = songs
artist_table_create =artists
time_table_create = time

songplay_table_insert = """INSERT INTO songplays (songplay_id, start_time, user_id, level, song_id, artist_id, session_id, 
location, user_agent) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s) ON CONFLICT (songplay_id) DO NOTHING;"""

user_table_insert = """INSERT INTO users (user_id, first_name, last_name, gender, level) VALUES (%s, %s, %s, %s, %s) 
ON CONFLICT (user_id) DO NOTHING;"""

song_table_insert = """INSERT INTO songs (song_id, title, artist_id, year, duration) VALUES (%s, %s, %s, %s, %s) 
ON CONFLICT (song_id) DO NOTHING;"""

artist_table_insert = """'INSERT INTO artists (artist_id, name, location, latitude, longitude) VALUES (%s, %s, %s, %s, %s) 
ON CONFLICT (artist_id) DO NOTHING;';"""


time_table_insert = '''INSERT INTO time (start_time, hour, day, week, month, year, weekday) 
VALUES (%s, %s, %s, %s, %s, %s, %s) ON CONFLICT (start_time) DO NOTHING;'''

# %%
if __name__ =='__main__':
    with Postgres() as p:
        p.create_database()
        p.connect_to_db()
        print(p._tables)
        p.create_table(queries)
        p.list_tables()
        for name in ['songplays', 'users', 'songs', 'artists', 'time']:
            p.print_columns(name)
            print('-------------')
        p.insert_data('users', users_data)
        p.print_data('users')
        print('------------------')
        p.insert_data('songs', songs_data)
        p.print_data('songs')
        print('------------------')
        p.insert_data('artists', artists_data)
        p.print_data('artists')
        print('------------------')
        p.insert_data('time', time_data)
        p.print_data('time')
        print('------------------')
        p.insert_data('songplays', songplays_data)
        p.print_data('songplays')
# Out:
# You have been conected to database: sparkifydb
# {}
# Table songplays created successfully!
# Table users created successfully!
# Table songs created successfully!
# Table artists created successfully!
# Table time created successfully!
# At your current DB you have the following tables: 'artists','songplays','songs','time','users'
# ['songplay_id', 'start_time', 'user_id', 'level', 'song_id', 'artist_id', 'session_id', 'location', 'user_agent']
# -------------
# ['user_id', 'first_name', 'last_name', 'gender', 'level']
# -------------
# ['song_id', 'title', 'artist_id', 'year', 'duration']
# -------------
# ['artist_id', 'name', 'location', 'latitude', 'longitude']
# -------------
# ['start_time', 'hour', 'day', 'week', 'month', 'year', 'weekday']
# -------------
# users
# user_id, first_name, last_name, gender, level
# (39, 'Walter', 'Frye', 'M', 'free')
# (8, 'Kaylee', 'Summers', 'F', 'free')
# (10, 'Sylvie', 'Cruz', 'F', 'free')
# (26, 'Ryan', 'Smith', 'M', 'free')
# (101, 'Jayden', 'Fox', 'M', 'free')
# (83, 'Stefany', 'White', 'F', 'free')
# (66, 'Kevin', 'Arellano', 'M', 'free')
# (48, 'Marina', 'Sutton', 'F', 'free')
# (86, 'Aiden', 'Hess', 'M', 'free')
# (17, 'Makinley', 'Jones', 'F', 'free')
# (15, 'Lily', 'Koch', 'F', 'paid')
# (89, 'Kynnedi', 'Sanchez', 'F', 'free')
# (80, 'Tegan', 'Levine', 'F', 'free')
# (44, 'Aleena', 'Kirby', 'F', 'paid')
# (88, 'Mohammad', 'Rodriguez', 'M', 'free')
# (49, 'Chloe', 'Cuevas', 'F', 'free')
# (100, 'Adler', 'Barrera', 'M', 'free')
# (61, 'Samuel', 'Gonzalez', 'M', 'free')
# (75, 'Joseph', 'Gutierrez', 'M', 'free')
# (50, 'Ava', 'Robinson', 'F', 'free')
# (12, 'Austin', 'Rosales', 'M', 'free')
# (71, 'Ayleen', 'Wise', 'F', 'free')
# (54, 'Kaleb', 'Cook', 'M', 'free')
# (3, 'Isaac', 'Valdez', 'M', 'free')
# (53, 'Celeste', 'Williams', 'F', 'free')
# (69, 'Anabelle', 'Simpson', 'F', 'free')
# (62, 'Connar', 'Moreno', 'M', 'free')
# (95, 'Sara', 'Johnson', 'F', 'paid')
# (63, 'Ayla', 'Johnson', 'F', 'free')
# (6, 'Cecilia', 'Owens', 'F', 'free')
# (52, 'Theodore', 'Smith', 'M', 'free')
# (99, 'Ann', 'Banks', 'F', 'free')
# (43, 'Jahiem', 'Miles', 'M', 'free')
# (25, 'Jayden', 'Graves', 'M', 'paid')
# (51, 'Maia', 'Burke', 'F', 'free')
# (16, 'Rylan', 'George', 'M', 'free')
# (32, 'Lily', 'Burns', 'F', 'free')
# (37, 'Jordan', 'Hicks', 'F', 'free')
# (28, 'Brantley', 'West', 'M', 'free')
# (77, 'Magdalene', 'Herman', 'F', 'free')
# (78, 'Chloe', 'Roth', 'F', 'free')
# (74, 'Braden', 'Parker', 'M', 'free')
# (55, 'Martin', 'Johnson', 'M', 'free')
# (33, 'Bronson', 'Harris', 'M', 'free')
# (73, 'Jacob', 'Klein', 'M', 'paid')
# (58, 'Emily', 'Benson', 'F', 'paid')
# (94, 'Noah', 'Chavez', 'M', 'free')
# (57, 'Katherine', 'Gay', 'F', 'free')
# (42, 'Harper', 'Barrett', 'M', 'paid')
# (60, 'Devin', 'Larson', 'M', 'free')
# (84, 'Shakira', 'Hunt', 'F', 'free')
# (91, 'Jayden', 'Bell', 'M', 'free')
# (24, 'Layla', 'Griffin', 'F', 'paid')
# (97, 'Kate', 'Harrell', 'F', 'paid')
# (35, 'Molly', 'Taylor', 'F', 'free')
# (81, 'Sienna', 'Colon', 'F', 'free')
# (27, 'Carlos', 'Carter', 'M', 'free')
# (29, 'Jacqueline', 'Lynch', 'F', 'free')
# (34, 'Evelin', 'Ayala', 'F', 'free')
# (30, 'Avery', 'Watkins', 'F', 'paid')
# (2, 'Jizelle', 'Benjamin', 'F', 'free')
# (92, 'Ryann', 'Smith', 'F', 'free')
# (9, 'Wyatt', 'Scott', 'M', 'free')
# (14, 'Theodore', 'Harris', 'M', 'free')
# (23, 'Morris', 'Gilmore', 'M', 'free')
# (98, 'Jordyn', 'Powell', 'F', 'free')
# (45, 'Dominick', 'Norris', 'M', 'free')
# (20, 'Aiden', 'Ramirez', 'M', 'paid')
# (11, 'Christian', 'Porter', 'F', 'free')
# (85, 'Kinsley', 'Young', 'F', 'free')
# (72, 'Hayden', 'Brock', 'F', 'paid')
# (36, 'Matthew', 'Jones', 'M', 'free')
# (7, 'Adelyn', 'Jordan', 'F', 'free')
# (64, 'Hannah', 'Calhoun', 'F', 'free')
# (47, 'Kimber', 'Norris', 'F', 'free')
# (67, 'Colm', 'Santana', 'M', 'free')
# (13, 'Ava', 'Robinson', 'F', 'free')
# (18, 'Jacob', 'Rogers', 'M', 'free')
# (96, 'Cierra', 'Finley', 'F', 'free')
# (41, 'Brayden', 'Clark', 'M', 'free')
# (68, 'Jordan', 'Rodriguez', 'F', 'free')
# (76, 'Jayden', 'Duffy', 'F', 'free')
# (40, 'Tucker', 'Garrison', 'M', 'free')
# (4, 'Alivia', 'Terrell', 'F', 'free')
# (59, 'Lily', 'Cooper', 'F', 'free')
# (19, 'Zachary', 'Thomas', 'M', 'free')
# (90, 'Andrea', 'Butler', 'F', 'free')
# (70, 'Jaleah', 'Hayes', 'F', 'paid')
# (79, 'James', 'Martin', 'M', 'free')
# (65, 'Amiya', 'Davidson', 'F', 'paid')
# (56, 'Cienna', 'Freeman', 'F', 'free')
# (87, 'Dustin', 'Lee', 'M', 'free')
# (21, 'Preston', 'Sanders', 'M', 'free')
# (38, 'Gianna', 'Jones', 'F', 'free')
# (5, 'Elijah', 'Davis', 'M', 'free')
# (82, 'Avery', 'Martinez', 'F', 'paid')
# (22, 'Sean', 'Wilson', 'F', 'free')
# ------------------
# songs
# song_id, title, artist_id, year, duration
# ('SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, 219)
# ('SOCIWDW12A8C13D406', 'Soul Deep', 'ARMJAGH1187FB546F3', 1969, 148)
# ('SOXVLOJ12AB0189215', 'Amor De Cabaret', 'ARKRRTF1187B9984DA', 0, 177)
# ('SONHOTT12A8C13493C', 'Something Girls', 'AR7G5I41187FB4CE6C', 1982, 233)
# ('SOFSOCN12A8C143F5D', 'Face the Ashes', 'ARXR32B1187FB57099', 2007, 210)
# ('SOYMRWW12A6D4FAB14', 'The Moon And I (Ordinary Day Album Version)', 'ARKFYS91187B98E58F', 0, 268)
# ('SOMJBYD12A6D4F8557', 'Keepin It Real (Skit)', 'ARD0S291187B9B7BF5', 0, 115)
# ('SOHKNRJ12A6701D1F8', 'Drop of Rain', 'AR10USD1187B99F3F1', 0, 190)
# ('SOIAZJW12AB01853F1', 'Pink World', 'AR8ZCNI1187B9A069B', 1984, 270)
# ('SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)', 'ARNTLGG11E2835DDB9', 0, 266)
# ('SOQHXMF12AB0182363', 'Young Boy Blues', 'ARGSJW91187B9B1D6B', 0, 219)
# ('SOKEJEJ12A8C13E0D0', 'The Urgency (LP Version)', 'ARC43071187B990240', 0, 245)
# ('SOMUYGI12AB0188633', 'La Culpa', 'ARL7K851187B99ACD2', 0, 226)
# ('SORAMLE12AB017C8B0', 'Auguri Cha Cha', 'ARHHO3O1187B989413', 0, 192)
# ('SOBONFF12A6D4F84D8', 'Tonight Will Be Alright', 'ARIK43K1187B9AE54C', 1986, 307)
# ('SOHUOAP12A8AE488E9', 'Floating', 'ARD842G1187B997376', 1987, 491)
# ('SOUQQEA12A8C134B1B', 'High Tide', 'ARIG6O41187B988BDD', 0, 229)
# ('SOILPQQ12AB017E82A', 'Sohna Nee Sohna Data', 'AR1ZHYZ1187FB3C717', 0, 599)
# ('SOXLBJT12A8C140925', 'Caught In A Dream', 'ARYKCQI1187FB3B18F', 2004, 290)
# ('SOZVMJI12AB01808AF', 'Synthetic Dream', 'ARNPAGP1241B9C7FD4', 0, 166)
# ('SOWTBJW12AC468AC6E', 'Broken-Down Merry-Go-Round', 'ARQGYP71187FB44566', 0, 152)
# ('SOBEBDG12A58A76D60', 'Kassie Jones', 'ARI3BMM1187FB4255E', 0, 221)
# ('SOZCTXZ12AB0182364', 'Setanta matins', 'AR5KOSW1187FB35FF4', 0, 270)
# ('SOBBUGU12A8C13E95D', 'Setting Fire to Sleeping Giants', 'ARMAC4T1187FB3FA4C', 2004, 208)
# ('SOBLGCN12AB0183212', 'James (Hold The Ladder Steady)', 'AR47JEX1187B995D81', 1985, 125)
# ('SOPSWQW12A6D4F8781', 'Made Like This (Live)', 'ARGIWFO1187B9B55B7', 0, 225)
# ('SOZQDIU12A58A7BCF6', 'Superconfidential', 'ARNTLGG11E2835DDB9', 0, 338)
# ('SONYPOM12A8C13B2D7', 'I Think My Wife Is Running Around On Me (Taco Hell)', 'ARDNS031187B9924F0', 2005, 186)
# ('SOBZBAZ12A6D4F8742', 'Spanish Grease', 'AROUOZZ1187B9ABE51', 1997, 168)
# ('SOVYKGO12AB0187199', 'Crazy Mixed Up World', 'ARH4Z031187B9A71F2', 1961, 156)
# ('SOGNCJP12A58A80271', 'Do You Finally Need A Friend', 'ARB29H41187B98F0EF', 1972, 343)
# ('SOLLHMX12AB01846DC', 'The Emperor Falls', 'AR1Y2PT1187FB5B9CE', 0, 485)
# ('SOYTPEP12AB0180E7B', 'Twist and Shout', 'ARAJPHH1187FB5566A', 1964, 165)
# ('SOGXHEG12AB018653E', 'It Makes No Difference Now', 'AR0RCMP1187FB3F427', 1992, 133)
# ('SOOLYAZ12A6701F4A6', 'Laws Patrolling (Album Version)', 'AREBBGV1187FB523D2', 0, 174)
# ('SOGOSOV12AF72A285E', '¿Dónde va Chichi?', 'ARGUVEV1187B98BA17', 1997, 313)
# ('SOQLGFP12A58A7800E', 'OAKtown', 'ARD7TVE1187B99BFB1', 0, 259)
# ('SOPVXLX12A8C1402D5', 'Larger Than Life', 'AR3JMC51187B9AE49D', 1999, 236)
# ('SOAOIBZ12AB01815BE', 'I Hold Your Hand In Mine [Live At Royal Albert Hall]', 'ARPBNLO1187FB3D52F', 2000, 43)
# ('SOZHPGD12A8C1394FE', 'Baby Come To Me', 'AR9AWNF1187B9AB0B4', 0, 237)
# ('SOSLAVG12A8C13397F', 'Den Pai Alo', 'AROGWRA122988FEE45', 0, 244)
# ('SOTTDKS12AB018D69B', 'It Wont Be Christmas', 'ARMBR4Y1187B9990EB', 0, 241)
# ('SOMVWWT12A58A7AE05', 'Knocked Out Of The Park', 'ARQ9BO41187FB5CF1F', 0, 183)
# ('SOQVMXR12A81C21483', 'Salt In NYC', 'ARKULSX1187FB45F84', 0, 424)
# ('SODUJBS12A8C132150', 'Wessex Loses a Bride', 'ARI2JSK1187FB496EF', 0, 112)
# ('SOBBXLX12A58A79DDA', 'Erica (2005 Digital Remaster)', 'AREDBBQ1187B98AFF5', 0, 139)
# ('SOTUKVB12AB0181477', 'Blessed Assurance', 'AR7ZKHQ1187B98DD73', 1993, 271)
# ('SOOJPRH12A8C141995', 'Loaded Like A Gun', 'ARBGXIG122988F409D', 0, 173)
# ('SOBCOSW12A8C13D398', 'Rumba De Barcelona', 'AR7SMBG1187B9B9066', 0, 218)
# ('SOQOTLQ12AB01868D0', 'Clementina Santafè', 'ARGCY1Y1187B9A4FA5', 0, 153)
# ('SOBKWDJ12A8C13B2F3', 'Wild Rose (Back 2 Basics Mix)', 'AR36F9J1187FB406F1', 0, 231)
# ('SOFNOQK12AB01840FC', 'Kutt Free (DJ Volume Remix)', 'ARNNKDK1187B98BBD5', 0, 407)
# ('SOGVQGJ12AB017F169', 'Ten Tonne', 'AR62SOJ1187FB47BB5', 2005, 338)
# ('SOFFKZS12AB017F194', 'A Higher Place (Album Version)', 'ARBEBBY1187B9B43DB', 1994, 236)
# ('SOBAYLL12A8C138AF9', 'Sono andati? Fingevo di dormire', 'ARDR4AC1187FB371A1', 0, 511)
# ('SOLEYHO12AB0188A85', 'Got My Mojo Workin', 'ARAGB2O1187FB3A161', 0, 338)
# ('SOPEGZN12AB0181B3D', 'Get Your Head Stuck On Your Neck', 'AREDL271187FB40F44', 0, 46)
# ('SOXILUQ12A58A7C72A', 'Jenny Take a Ride', 'ARP6N5A1187B99D1A3', 2004, 207)
# ('SOTCKKY12AB018A141', 'Sonnerie lalaleulé hi houuu', 'ARGSAFR1269FB35070', 0, 30)
# ('SOSWKAV12AB018FC91', 'Midnight Star', 'ARULZCI1241B9C8611', 0, 336)
# ('SONSKXP12A8C13A2C9', 'Native Soul', 'AR0IAWL1187B9A96D0', 2003, 197)
# ('SOUPIRU12A6D4FA1E1', 'Der Kleine Dompfaff', 'ARJIE2Y1187B994AB7', 0, 153)
# ('SODREIN12A58A7F2E5', 'A Whiter Shade Of Pale (Live @ Fillmore West)', 'ARLTWXK1187FB5A3F8', 0, 326)
# ('SONWXQJ12A8C134D94', 'The Ballad Of Sleeping Beauty', 'ARNF6401187FB57032', 1994, 305)
# ('SOWQTQZ12A58A7B63E', 'Streets On Fire (Explicit Album Version)', 'ARPFHN61187FB575F6', 0, 280)
# ('SOLYIBD12A8C135045', 'Music is what we love', 'AR051KA1187B98B2FF', 0, 262)
# ('SOINLJW12A8C13314C', 'City Slickers', 'AR8IEZO1187B99055E', 2008, 150)
# ('SOGDBUF12A8C140FAA', 'Intro', 'AR558FS1187FB45658', 2003, 76)
# ('SORRZGD12A6310DBC3', 'Harajuku Girls', 'ARVBRGZ1187FB4675A', 2004, 291)
# ('SODAUVL12A8C13D184', 'Prognosis', 'ARWB3G61187FB49404', 2000, 364)
# ('SOFCHDR12AB01866EF', 'Living Hell', 'AREVWGE1187B9B890A', 0, 282)
# ------------------
# artists
# artist_id, name, location, latitude, longitude
# ('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', nan, nan)
# ('ARMJAGH1187FB546F3', 'The Box Tops', 'Memphis, TN', 35.14968, -90.04892)
# ('ARKRRTF1187B9984DA', 'Sonora Santanera', '', nan, nan)
# ('AR7G5I41187FB4CE6C', 'Adam Ant', 'London, England', nan, nan)
# ('ARXR32B1187FB57099', 'Gob', '', nan, nan)
# ('ARKFYS91187B98E58F', 'Jeff And Sheri Easter', '', nan, nan)
# ('ARD0S291187B9B7BF5', 'Rated R', 'Ohio', nan, nan)
# ('AR10USD1187B99F3F1', 'Tweeterfriendly Music', 'Burlington, Ontario, Canada', nan, nan)
# ('AR8ZCNI1187B9A069B', 'Planet P Project', '', nan, nan)
# ('ARNTLGG11E2835DDB9', 'Clp', '', nan, nan)
# ('ARGSJW91187B9B1D6B', 'JennyAnyKind', 'North Carolina', 35.21962, -80.01955)
# ('ARC43071187B990240', 'Wayne Watson', 'Wisner, LA', nan, nan)
# ('ARL7K851187B99ACD2', 'Andy Andy', '', nan, nan)
# ('ARHHO3O1187B989413', 'Bob Azzam', '', nan, nan)
# ('ARIK43K1187B9AE54C', 'Lionel Richie', 'Beverly Hills, CA', nan, nan)
# ('ARD842G1187B997376', 'Blue Rodeo', 'Toronto, Ontario, Canada', 43.64856, -79.38533)
# ('ARIG6O41187B988BDD', 'Richard Souther', 'United States', 37.16793, -95.84502)
# ('AR1ZHYZ1187FB3C717', 'Faiz Ali Faiz', '', nan, nan)
# ('ARYKCQI1187FB3B18F', 'Tesla', '', nan, nan)
# ('ARNPAGP1241B9C7FD4', 'lextrical', '', nan, nan)
# ('ARQGYP71187FB44566', 'Jimmy Wakely', 'Mineola, AR', 34.31109, -94.02978)
# ('ARI3BMM1187FB4255E', 'Alice Stuart', 'Washington', 38.8991, -77.029)
# ('AR5KOSW1187FB35FF4', 'Elena', 'Dubai UAE', 49.80388, 15.47491)
# ('ARMAC4T1187FB3FA4C', 'The Dillinger Escape Plan', 'Morris Plains, NJ', 40.82624, -74.47995)
# ('AR47JEX1187B995D81', 'SUE THOMPSON', 'Nevada, MO', 37.83721, -94.35868)
# ('ARGIWFO1187B9B55B7', 'Five Bolt Main', '', nan, nan)
# ('ARDNS031187B9924F0', 'Tim Wilson', 'Georgia', 32.67828, -83.22295)
# ('AROUOZZ1187B9ABE51', 'Willie Bobo', 'New York, NY [Spanish Harlem]', 40.79195, -73.94512)
# ('ARH4Z031187B9A71F2', 'Faye Adams', 'Newark, NJ', 40.73197, -74.17418)
# ('ARB29H41187B98F0EF', 'Terry Callier', 'Chicago', 41.88415, -87.63241)
# ('AR1Y2PT1187FB5B9CE', 'John Wesley', 'Brandon', 27.94017, -82.32547)
# ('ARAJPHH1187FB5566A', 'The Shangri-Las', 'Queens, NY', 40.7038, -73.83168)
# ('AR0RCMP1187FB3F427', 'Billie Jo Spears', 'Beaumont, TX', 30.08615, -94.10158)
# ('AREBBGV1187FB523D2', "Mike Jones (Featuring CJ_ Mello & Lil' Bran)", 'Houston, TX', nan, nan)
# ('ARGUVEV1187B98BA17', 'Sierra Maestra', '', nan, nan)
# ('AR3JMC51187B9AE49D', 'Backstreet Boys', 'Orlando, FL', 28.53823, -81.37739)
# ('ARPBNLO1187FB3D52F', 'Tiny Tim', 'New York, NY', 40.71455, -74.00712)
# ('AR9AWNF1187B9AB0B4', 'Kenny G featuring Daryl Hall', 'Seattle, Washington USA', nan, nan)
# ('AROGWRA122988FEE45', 'Christos Dantis', '', nan, nan)
# ('ARMBR4Y1187B9990EB', 'David Martin', 'California - SF', 37.77916, -122.42005)
# ('ARQ9BO41187FB5CF1F', 'John Davis', 'Pennsylvania', 40.99471, -77.60454)
# ('ARKULSX1187FB45F84', 'Trafik', 'Utah', 39.49974, -111.54732)
# ('ARI2JSK1187FB496EF', 'Nick Ingman;Gavyn Wright', 'London, England', 51.50632, -0.12714)
# ('AREDBBQ1187B98AFF5', 'Eddie Calvert', '', nan, nan)
# ('AR7ZKHQ1187B98DD73', 'Glad', '', nan, nan)
# ('ARBGXIG122988F409D', 'Steel Rain', 'California - SF', 37.77916, -122.42005)
# ('AR7SMBG1187B9B9066', 'Los Manolos', '', nan, nan)
# ('ARGCY1Y1187B9A4FA5', 'Gloriana', 'Nashville, TN.', 36.16778, -86.77836)
# ('AR36F9J1187FB406F1', 'Bombay Rockers', 'Denmark', 56.27609, 9.51695)
# ('ARNNKDK1187B98BBD5', 'Jinx', 'Zagreb Croatia', 45.80726, 15.967600000000001)
# ('AR62SOJ1187FB47BB5', 'Chase & Status', '', nan, nan)
# ('ARBEBBY1187B9B43DB', 'Tom Petty', 'Gainesville, FL', nan, nan)
# ('ARDR4AC1187FB371A1', 'Montserrat Caballé;Placido Domingo;Vicente Sardinero;Judith Blegen;Sherrill Milnes;Georg Solti', '', nan, nan)
# ('ARAGB2O1187FB3A161', 'Pucho & His Latin Soul Brothers', '', nan, nan)
# ('AREDL271187FB40F44', 'Soul Mekanik', '', nan, nan)
# ('ARP6N5A1187B99D1A3', 'Mitch Ryder', 'Hamtramck, MI', nan, nan)
# ('ARGSAFR1269FB35070', 'Blingtones', '', nan, nan)
# ('ARULZCI1241B9C8611', 'Luna Orbit Project', '', nan, nan)
# ('AR0IAWL1187B9A96D0', 'Danilo Perez', 'Panama', 8.4177, -80.11278)
# ('ARJIE2Y1187B994AB7', 'Line Renaud', '', nan, nan)
# ('ARLTWXK1187FB5A3F8', 'King Curtis', 'Fort Worth, TX', 32.74863, -97.32925)
# ('ARNF6401187FB57032', 'Sophie B. Hawkins', 'New York, NY [Manhattan]', 40.79086, -73.96644)
# ('ARPFHN61187FB575F6', 'Lupe Fiasco', 'Chicago, IL', 41.88415, -87.63241)
# ('AR051KA1187B98B2FF', 'Wilks', '', nan, nan)
# ('AR8IEZO1187B99055E', 'Marc Shaiman', '', nan, nan)
# ('AR558FS1187FB45658', '40 Grit', '', nan, nan)
# ('ARVBRGZ1187FB4675A', 'Gwen Stefani', '', nan, nan)
# ('ARWB3G61187FB49404', 'Steve Morse', 'Hamilton, Ohio', nan, nan)
# ('AREVWGE1187B9B890A', 'Bitter End', 'Noci (BA)', -13.442, -41.9952)
# ------------------
# time
# start_time, hour, day, week, month, year, weekday
# (datetime.datetime(2018, 11, 1, 20, 57, 10, 796000), 20, 1, 44, 11, 2018, 3)
# (datetime.datetime(2018, 11, 1, 21, 1, 46, 796000), 21, 1, 44, 11, 2018, 3)
# (datetime.datetime(2018, 11, 1, 21, 2, 12, 796000), 21, 1, 44, 11, 2018, 3)
# (datetime.datetime(2018, 11, 1, 21, 5, 52, 796000), 21, 1, 44, 11, 2018, 3)
 4, 44, 11, 2018, 6)
# (datetime.datetime(2018, 11, 4, 15, 2, 51, 796000), 15, 4, 44, 11, 2018, 6)
# (datetime.datetime(2018, 11, 4, 15, 7, 51, 796000), 15, 4, 44, 11, 2018, 6)
# (datetime.datetime(2018, 11, 4, 15, 25, 29, 796000), 15, 4, 44, 11, 2018, 6)
# (datetime.datetime(2018, 11, 4, 15, 25, 42, 796000), 15, 4, 44, 11, 2018, 6)
# (datetime.datetime(2018, 11, 4, 15, 26, 51, 796000), 15, 4, 44, 11, 2018, 6)
# (datetime.datetime(2018, 11, 4, 15, 29, 41, 796000), 15, 4, 44, 11, 2018, 6)
# (datetime.datetime(2018, 11, 4, 15, 32, 23, 796000), 15, 4, 44, 11, 2018, 6)
# (datetime.datetime(2018, 11, 4, 15, 33, 26, 796000), 15, 4, 44, 11, 2018, 6)
# (datetime.datetime(2018, 11, 4, 15, 39, 36, 796000), 15, 4, 44, 11, 2018, 6)
# (datetime.datetime(2018, 11, 4, 16, 8, 51, 796000), 16, 4, 44, 11, 2018, 6)
# (datetime.datetime(2018, 11, 4, 16, 18, 48, 796000), 16, 4, 44, 11, 2018, 6)
# (datetime.datetime(2018, 11, 4, 16, 23, 7, 796000), 16, 4, 44, 11, 2018, 6)
# (datetime.datetime(2018, 11, 4, 16, 25, 54, 796000), 16, 4, 44, 11, 2018, 6)
# ...
# (7986, datetime.datetime(2018, 11, 30, 15, 5, 56, 796000), 85, 'paid', 'NaN', 'NaN', 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (7987, datetime.datetime(2018, 11, 30, 15, 6, 38, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (7988, datetime.datetime(2018, 11, 30, 15, 10, 7, 796000), 85, 'paid', 'NaN', 'NaN', 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (7989, datetime.datetime(2018, 11, 30, 15, 11, 47, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (7990, datetime.datetime(2018, 11, 30, 15, 12, 54, 796000), 36, 'paid', 'NaN', 'NaN', 1100, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (7991, datetime.datetime(2018, 11, 30, 15, 13, 3, 796000), 88, 'paid', 'NaN', 'NaN', 1097, 'Sacramento--Roseville--Arden-Arcade, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (7992, datetime.datetime(2018, 11, 30, 15, 14, 35, 796000), 85, 'paid', 'NaN', 'NaN', 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (7993, datetime.datetime(2018, 11, 30, 15, 16, 2, 796000), 36, 'paid', 'NaN', 'NaN', 1100, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (7994, datetime.datetime(2018, 11, 30, 15, 17, 7, 796000), 85, 'paid', 'NaN', 'NaN', 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (7995, datetime.datetime(2018, 11, 30, 15, 21, 29, 796000), 85, 'paid', 'NaN', 'NaN', 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (7996, datetime.datetime(2018, 11, 30, 16, 12, 3, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (7997, datetime.datetime(2018, 11, 30, 15, 22, 54, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (7998, datetime.datetime(2018, 11, 30, 15, 27, 25, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (7999, datetime.datetime(2018, 11, 30, 15, 28, 30, 796000), 85, 'paid', 'NaN', 'NaN', 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (8000, datetime.datetime(2018, 11, 30, 15, 32, 0, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8001, datetime.datetime(2018, 11, 30, 15, 42, 22, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8002, datetime.datetime(2018, 11, 30, 15, 46, 15, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8003, datetime.datetime(2018, 11, 30, 15, 50, 8, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8004, datetime.datetime(2018, 11, 30, 15, 57, 42, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8005, datetime.datetime(2018, 11, 30, 15, 58, 51, 796000), 49, 'paid', 'NaN', 'NaN', 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (8006, datetime.datetime(2018, 11, 30, 16, 6, 15, 796000), 49, 'paid', 'NaN', 'NaN', 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (8007, datetime.datetime(2018, 11, 30, 16, 15, 19, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8008, datetime.datetime(2018, 11, 30, 16, 20, 4, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8009, datetime.datetime(2018, 11, 30, 16, 25, 17, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8010, datetime.datetime(2018, 11, 30, 16, 31, 25, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8011, datetime.datetime(2018, 11, 30, 16, 34, 12, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8012, datetime.datetime(2018, 11, 30, 16, 38, 10, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8013, datetime.datetime(2018, 11, 30, 16, 39, 12, 796000), 33, 'free', 'NaN', 'NaN', 1026, 'Eugene, OR', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (8014, datetime.datetime(2018, 11, 30, 16, 41, 23, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8015, datetime.datetime(2018, 11, 30, 16, 43, 28, 796000), 33, 'free', 'NaN', 'NaN', 1026, 'Eugene, OR', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (8016, datetime.datetime(2018, 11, 30, 16, 45, 28, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8017, datetime.datetime(2018, 11, 30, 16, 49, 6, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8018, datetime.datetime(2018, 11, 30, 16, 55, 41, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8019, datetime.datetime(2018, 11, 30, 17, 3, 3, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8020, datetime.datetime(2018, 11, 30, 17, 7, 22, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8021, datetime.datetime(2018, 11, 30, 17, 11, 16, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8022, datetime.datetime(2018, 11, 30, 17, 16, 14, 796000), 49, 'paid', 'NaN', 'NaN', 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (8023, datetime.datetime(2018, 11, 30, 17, 19, 28, 796000), 49, 'paid', 'NaN', 'NaN', 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (8024, datetime.datetime(2018, 11, 30, 17, 19, 58, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8025, datetime.datetime(2018, 11, 30, 17, 22, 1, 796000), 49, 'paid', 'NaN', 'NaN', 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (8026, datetime.datetime(2018, 11, 30, 17, 24, 7, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8027, datetime.datetime(2018, 11, 30, 17, 28, 37, 796000), 49, 'paid', 'NaN', 'NaN', 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (8028, datetime.datetime(2018, 11, 30, 17, 30, 27, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8029, datetime.datetime(2018, 11, 30, 17, 31, 24, 796000), 49, 'paid', 'NaN', 'NaN', 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (8030, datetime.datetime(2018, 11, 30, 17, 34, 27, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8031, datetime.datetime(2018, 11, 30, 17, 35, 7, 796000), 49, 'paid', 'NaN', 'NaN', 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (8032, datetime.datetime(2018, 11, 30, 17, 39, 8, 796000), 49, 'paid', 'NaN', 'NaN', 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (8033, datetime.datetime(2018, 11, 30, 17, 44, 0, 796000), 49, 'paid', 'NaN', 'NaN', 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (8034, datetime.datetime(2018, 11, 30, 17, 45, 41, 796000), 49, 'paid', 'NaN', 'NaN', 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (8035, datetime.datetime(2018, 11, 30, 17, 53, 44, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8036, datetime.datetime(2018, 11, 30, 17, 54, 43, 796000), 49, 'paid', 'NaN', 'NaN', 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (8037, datetime.datetime(2018, 11, 30, 17, 57, 24, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8038, datetime.datetime(2018, 11, 30, 17, 58, 43, 796000), 49, 'paid', 'NaN', 'NaN', 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (8039, datetime.datetime(2018, 11, 30, 18, 3, 19, 796000), 49, 'paid', 'NaN', 'NaN', 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (8040, datetime.datetime(2018, 11, 30, 18, 4, 23, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8041, datetime.datetime(2018, 11, 30, 18, 8, 7, 796000), 49, 'paid', 'NaN', 'NaN', 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (8042, datetime.datetime(2018, 11, 30, 18, 14, 56, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8043, datetime.datetime(2018, 11, 30, 18, 16, 20, 796000), 91, 'free', 'NaN', 'NaN', 1085, 'Dallas-Fort Worth-Arlington, TX', 'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)')
# (8044, datetime.datetime(2018, 11, 30, 18, 19, 33, 796000), 49, 'paid', 'NaN', 'NaN', 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (8045, datetime.datetime(2018, 11, 30, 18, 24, 5, 796000), 49, 'paid', 'NaN', 'NaN', 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (8046, datetime.datetime(2018, 11, 30, 18, 26, 12, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8047, datetime.datetime(2018, 11, 30, 18, 28, 8, 796000), 49, 'paid', 'NaN', 'NaN', 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (8048, datetime.datetime(2018, 11, 30, 18, 31, 34, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8049, datetime.datetime(2018, 11, 30, 18, 35, 19, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8050, datetime.datetime(2018, 11, 30, 18, 36, 25, 796000), 49, 'paid', 'NaN', 'NaN', 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (8051, datetime.datetime(2018, 11, 30, 18, 39, 22, 796000), 49, 'paid', 'NaN', 'NaN', 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (8052, datetime.datetime(2018, 11, 30, 18, 44, 36, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8053, datetime.datetime(2018, 11, 30, 18, 47, 58, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8054, datetime.datetime(2018, 11, 30, 18, 51, 24, 796000), 16, 'paid', 'NaN', 'NaN', 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (8055, datetime.datetime(2018, 11, 30, 19, 54, 24, 796000), 5, 'free', 'NaN', 'NaN', 985, 'Detroit-Warren-Dearborn, MI', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# Conection closed!
